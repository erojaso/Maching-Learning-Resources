# %% [markdown]
# # Chapter 16 - Backtest Forecast Models
#
# The goal of time series forecasting is to make accurate predictions about the future. The fast and powerful methods that we rely on in machine learning, such as using train-test splits and k-fold cross-validation, do not work in the case of time series data. This is because they ignore the temporal components inherent in the problem.
#
# After completing this tutorial, you will know:
# - The limitations of traditional methods of model evaluation from machine learning and why evaluating models on out-of-sample data is required.
# - How to create train-test splits and multiple train-test splits of time series data for model evaluation in Python.
# - How walk-forward validation provides the most realistic evaluation of machine learning models on time series data.
#
# ## 16.1 Model Evaluation
#
# How do we know how good a given model is? We could evaluate it on the data used to train it. This would be invalid. It might provide insight into how the selected model works, and even how it may be improved. But, any estimate of performance on this data would be optimistic, and any decisions based on this performance would be biased.
#
# In applied machine learning, we often split our data into a train and a test set: the training set used to prepare the model and the test set used to evaluate it. We may even use k-fold cross-validation that repeats this process by systematically splitting the data into k groups, each given a chance to be a held out model.
#
# We will look at three different methods that you can use to backtest your machine learning models on time series problems. They are:
# 1. Train-Test split that respect temporal order of observations.
# 2. Multiple Train-Test splits that respect temporal order of observations.
# 3. Walk-Forward Validation where a model may be updated each time step new data is received.
#
# ## 16.2 Monthly Sunspots Dataset
#
# This dataset describes a monthly count of the number of observed sunspots for just over 230 years (1749-1983).
#
# ## 16.3 Train-Test Split
#
# You can split your dataset into training and testing subsets. Your model can be prepared on the training dataset and predictions can be made and evaluated for the test dataset. This can be done by selecting an arbitrary split point in the ordered list of observations and creating two new datasets.

# %%
# calculate a train-test split of a time series dataset
from pandas import read_csv
from pylab import rcParams

csvfile = '.\\code\\chapter_16\\sunspots.csv'

series = read_csv(csvfile, header=0, index_col=0, parse_dates=True, squeeze=True)

X = series.values
train_size = int(len(X) * 0.66)
train, test = X[0:train_size], X[train_size:len(X)]

print('Observations: %d' % (len(X)))
print('Training Observations: %d' % (len(train)))
print('Testing Observations: %d' % (len(test)))
# Out:
# Observations: 2820
# Training Observations: 1861
# Testing Observations: 959

# %%
# plot train-test split of time series data
from pandas import read_csv
from matplotlib import pyplot

# %matplotlib inline

csvfile = '.\\code\\chapter_16\\sunspots.csv'

series = read_csv(csvfile, header=0, index_col=0, parse_dates=True, squeeze=True)

X = series.values
train_size = int(len(X) * 0.66)
train, test = X[0:train_size], X[train_size:len(X)]
print('Observations: %d' % (len(X)))
print('Training Observations: %d' % (len(train)))
print('Testing Observations: %d' % (len(test)))

rcParams['figure.figsize'] = 15, 5
pyplot.plot(train)
pyplot.plot([None for i in train] + [x for x in test])
pyplot.show()
# Out:
# Observations: 2820
# Training Observations: 1861
# Testing Observations: 959

# %% [markdown]
# Using a train-test split method to evaluate machine learning models is fast. Preparing the data is simple and intuitive and only one model is created and evaluated. It is useful when you have a large amount of data so that both training and tests sets are representative of the original problem.
#
# ## 16.4 Multiple Train-Test Splits
#
# We can repeat the process of splitting the time series into train and test sets multiple times. This will require multiple models to be trained and evaluated, but this additional computational expense will provide a more robust estimate of the expected performance of the chosen method and conguration on unseen data.
#
# The dataset has 2,820 observations. Let's create 3 splits for the dataset. Using the same arithmetic above, we would expect the following train and test splits to be created:
# - Split 1: 705 train, 705 test
# - Split 2: 1,410 train, 705 test
# - Split 3: 2,115 train, 705 test

# %%
# calculate repeated train-test splits of time series data
from pandas import read_csv
from sklearn.model_selection import TimeSeriesSplit
from matplotlib import pyplot

csvfile = '.\\code\\chapter_16\\sunspots.csv'

series = read_csv(csvfile, header=0, index_col=0, parse_dates=True, squeeze=True)

X = series.values
splits = TimeSeriesSplit(n_splits=3)
pyplot.figure(1)
index = 1
for train_index, test_index in splits.split(X):
    train = X[train_index]
    test = X[test_index]    
    print('Training Observations: %d' % (len(train)))
    print('Testing Observations: %d' % (len(test)))
    print('Observations: %d' % (len(train) + len(test)))
    print('-----')

    pyplot.subplot(310 + index)
    pyplot.plot(train)
    pyplot.plot([None for i in train] + [x for x in test])
    
    index += 1

pyplot.show()
# Out:
# Training Observations: 705
# Testing Observations: 705
# Observations: 1410
# -----
# Training Observations: 1410
# Testing Observations: 705
# Observations: 2115
# -----
# Training Observations: 2115
# Testing Observations: 705
# Observations: 2820
# -----

# %% [markdown]
# Using multiple train-test splits will result in more models being trained, and in turn, a more accurate estimate of the performance of the models on unseen data. **A limitation of the train-test split approach is that the trained models remain fixed as they are evaluated on each evaluation in the test set**. This may not be realistic as models can be retrained as new daily or monthly observations are made available. This concern is addressed in the next section.
#
# ## 16.5 Walk Forward Validation
#
# In practice, we very likely will retrain our model as new data becomes available. This would give the model the best opportunity to make good forecasts at each time step. We can evaluate our machine learning models under this assumption.
#
# Because this methodology involves moving along the time series one-time step at a time, it is often called Walk Forward Testing or Walk Forward Validation. Additionally, because a sliding or expanding window is used to train a model, this method is also referred to as Rolling Window Analysis or a Rolling Forecast.

# %%
# walk forward evaluation model for time series data
from pandas import read_csv

csvfile = '.\\code\\chapter_16\\sunspots.csv'

series = read_csv(csvfile, header=0, index_col=0, parse_dates=True, squeeze=True)

X = series.values
n_train = 500
n_records = len(X)
for i in range(n_train, n_records):
    train, test = X[0:i], X[i:i+1]
    print('train=%d, test=%.2f' % (len(train), test))
    #print('train=%d, test=%d' % (len(train), len(test)))
# Out:
# n=1954, test=4.20
# train=1955, test=2.20
# train=1956, test=0.30
# train=1957, test=0.00
# train=1958, test=4.90
# train=1959, test=4.50
# train=1960, test=4.40
# train=1961, test=4.10
# train=1962, test=3.00
# train=1963, test=0.30
# train=1964, test=9.50
# train=1965, test=4.60
# train=1966, test=1.10
# train=1967, test=6.40
# train=1968, test=2.30
# train=1969, test=2.90
# train=1970, test=0.50
# train=1971, test=0.90
# train=1972, test=0.00
# train=1973, test=0.00
# train=1974, test=1.70
# train=1975, test=0.20
# train=1976, test=1.20
# train=1977, test=3.10
# train=1978, test=0.70
# train=1979, test=3.80
# train=1980, test=2.80
# train=1981, test=2.60
# train=1982, test=3.10
# train=1983, test=17.30
# train=1984, test=5.20
# train=1985, test=11.40
# train=1986, test=5.40
# train=1987, test=7.70
# train=1988, test=12.70
# train=1989, test=8.20
# train=1990, test=16.40
# train=1991, test=22.30
# train=1992, test=23.00
# train=1993, test=42.30
# train=1994, test=38.80
# train=1995, test=41.30
# train=1996, test=33.00
# train=1997, test=68.80
# train=1998, test=71.60
# train=1999, test=69.60
# train=2000, test=49.50
# train=2001, test=53.50
# train=2002, test=42.50
# train=2003, test=34.50
# train=2004, test=45.30
# train=2005, test=55.40
# train=2006, test=67.00
# train=2007, test=71.80
# train=2008, test=74.50
# train=2009, test=67.70
# train=2010, test=53.50
# train=2011, test=35.20
# train=2012, test=45.10
# train=2013, test=50.70
# train=2014, test=65.60
# train=2015, test=53.00
# train=2016, test=74.70
# train=2017, test=71.90
# train=2018, test=94.80
# train=2019, test=74.70
# train=2020, test=114.10
# train=2021, test=114.90
# train=2022, test=119.80
# train=2023, test=154.50
# train=2024, test=129.40
# train=2025, test=72.20
# train=2026, test=96.40
# train=2027, test=129.30
# train=2028, test=96.00
# train=2029, test=65.30
# train=2030, test=72.20
# train=2031, test=80.50
# train=2032, test=76.70
# train=2033, test=59.40
# train=2034, test=107.60
# train=2035, test=101.70
# train=2036, test=79.90
# train=2037, test=85.00
# train=2038, test=83.40
# train=2039, test=59.20
# train=2040, test=48.10
# train=2041, test=79.50
# train=2042, test=66.50
# train=2043, test=51.80
# train=2044, test=88.10
# train=2045, test=111.20
# train=2046, test=64.70
# train=2047, test=69.00
# train=2048, test=54.70
# train=2049, test=52.80
# train=2050, test=42.00
# train=2051, test=34.90
# train=2052, test=51.10
# train=2053, test=53.90
# train=2054, test=70.20
# train=2055, test=14.80
# train=2056, test=33.30
# train=2057, test=38.70
# train=2058, test=27.50
# train=2059, test=19.20
# train=2060, test=36.30
# train=2061, test=49.60
# train=2062, test=27.20
# train=2063, test=29.90
# train=2064, test=31.50
# train=2065, test=28.30
# train=2066, test=26.70
# train=2067, test=32.40
# train=2068, test=22.20
# train=2069, test=33.70
# train=2070, test=41.90
# train=2071, test=22.80
# train=2072, test=17.80
# train=2073, test=18.20
# train=2074, test=17.80
# train=2075, test=20.30
# train=2076, test=11.80
# train=2077, test=26.40
# train=2078, test=54.70
# train=2079, test=11.00
# train=2080, test=8.00
# train=2081, test=5.80
# train=2082, test=10.90
# train=2083, test=6.50
# train=2084, test=4.70
# train=2085, test=6.20
# train=2086, test=7.40
# train=2087, test=17.50
# train=2088, test=4.50
# train=2089, test=1.50
# train=2090, test=3.30
# train=2091, test=6.10
# train=2092, test=3.20
# train=2093, test=9.10
# train=2094, test=3.50
# train=2095, test=0.50
# train=2096, test=13.20
# train=2097, test=11.60
# train=2098, test=10.00
# train=2099, test=2.80
# train=2100, test=0.50
# train=2101, test=5.10
# train=2102, test=1.80
# train=2103, test=11.30
# train=2104, test=20.80
# train=2105, test=24.00
# train=2106, test=28.10
# train=2107, test=19.30
# train=2108, test=25.10
# train=2109, test=25.60
# train=2110, test=22.50
# train=2111, test=16.50
# train=2112, test=5.50
# train=2113, test=23.20
# train=2114, test=18.00
# train=2115, test=31.70
# train=2116, test=42.80
# train=2117, test=47.50
# train=2118, test=38.50
# train=2119, test=37.90
# train=2120, test=60.20
# train=2121, test=69.20
# train=2122, test=58.60
# train=2123, test=98.60
# train=2124, test=71.80
# train=2125, test=70.00
# train=2126, test=62.50
# train=2127, test=38.50
# train=2128, test=64.30
# train=2129, test=73.50
# train=2130, test=52.30
# train=2131, test=61.60
# train=2132, test=60.80
# train=2133, test=71.50
# train=2134, test=60.50
# train=2135, test=79.40
# train=2136, test=81.60
# train=2137, test=93.00
# train=2138, test=69.60
# train=2139, test=93.50
# train=2140, test=79.10
# train=2141, test=59.10
# train=2142, test=54.90
# train=2143, test=53.80
# train=2144, test=68.40
# train=2145, test=63.10
# train=2146, test=67.20
# train=2147, test=45.20
# train=2148, test=83.50
# train=2149, test=73.50
# train=2150, test=85.40
# train=2151, test=80.60
# train=2152, test=76.90
# train=2153, test=91.40
# train=2154, test=98.00
# train=2155, test=83.80
# train=2156, test=89.70
# train=2157, test=61.40
# train=2158, test=50.30
# train=2159, test=59.00
# train=2160, test=68.90
# train=2161, test=64.10
# train=2162, test=50.20
# train=2163, test=52.80
# train=2164, test=58.20
# train=2165, test=71.90
# train=2166, test=70.20
# train=2167, test=65.80
# train=2168, test=34.40
# train=2169, test=54.00
# train=2170, test=81.10
# train=2171, test=108.00
# train=2172, test=65.30
# train=2173, test=49.20
# train=2174, test=35.00
# train=2175, test=38.20
# train=2176, test=36.80
# train=2177, test=28.80
# train=2178, test=21.90
# train=2179, test=24.90
# train=2180, test=32.10
# train=2181, test=34.40
# train=2182, test=35.60
# train=2183, test=25.80
# train=2184, test=14.60
# train=2185, test=43.10
# train=2186, test=30.00
# train=2187, test=31.20
# train=2188, test=24.60
# train=2189, test=15.30
# train=2190, test=17.40
# train=2191, test=13.00
# train=2192, test=19.00
# train=2193, test=10.00
# train=2194, test=18.70
# train=2195, test=17.80
# train=2196, test=12.10
# train=2197, test=10.60
# train=2198, test=11.20
# train=2199, test=11.20
# train=2200, test=17.90
# train=2201, test=22.20
# train=2202, test=9.60
# train=2203, test=6.80
# train=2204, test=4.00
# train=2205, test=8.90
# train=2206, test=8.20
# train=2207, test=11.00
# train=2208, test=12.30
# train=2209, test=22.20
# train=2210, test=10.10
# train=2211, test=2.90
# train=2212, test=3.20
# train=2213, test=5.20
# train=2214, test=2.80
# train=2215, test=0.20
# train=2216, test=5.10
# train=2217, test=3.00
# train=2218, test=0.60
# train=2219, test=0.30
# train=2220, test=3.40
# train=2221, test=7.80
# train=2222, test=4.30
# train=2223, test=11.30
# train=2224, test=19.70
# train=2225, test=6.70
# train=2226, test=9.30
# train=2227, test=8.30
# train=2228, test=4.00
# train=2229, test=5.70
# train=2230, test=8.70
# train=2231, test=15.40
# train=2232, test=18.90
# train=2233, test=20.50
# train=2234, test=23.10
# train=2235, test=12.20
# train=2236, test=27.30
# train=2237, test=45.70
# train=2238, test=33.90
# train=2239, test=30.10
# train=2240, test=42.10
# train=2241, test=53.20
# train=2242, test=64.20
# train=2243, test=61.50
# train=2244, test=62.80
# train=2245, test=74.30
# train=2246, test=77.10
# train=2247, test=74.90
# train=2248, test=54.60
# train=2249, test=70.00
# train=2250, test=52.30
# train=2251, test=87.00
# train=2252, test=76.00
# train=2253, test=89.00
# train=2254, test=115.40
# train=2255, test=123.40
# train=2256, test=132.50
# train=2257, test=128.50
# train=2258, test=83.90
# train=2259, test=109.30
# train=2260, test=116.70
# train=2261, test=130.30
# train=2262, test=145.10
# train=2263, test=137.70
# train=2264, test=100.70
# train=2265, test=124.90
# train=2266, test=74.40
# train=2267, test=88.80
# train=2268, test=98.40
# train=2269, test=119.20
# train=2270, test=86.50
# train=2271, test=101.00
# train=2272, test=127.40
# train=2273, test=97.50
# train=2274, test=165.30
# train=2275, test=115.70
# train=2276, test=89.60
# train=2277, test=99.10
# train=2278, test=122.20
# train=2279, test=92.70
# train=2280, test=80.30
# train=2281, test=77.40
# train=2282, test=64.60
# train=2283, test=109.10
# train=2284, test=118.30
# train=2285, test=101.00
# train=2286, test=97.60
# train=2287, test=105.80
# train=2288, test=112.60
# train=2289, test=88.10
# train=2290, test=68.10
# train=2291, test=42.10
# train=2292, test=50.50
# train=2293, test=59.40
# train=2294, test=83.30
# train=2295, test=60.70
# train=2296, test=54.40
# train=2297, test=83.90
# train=2298, test=67.50
# train=2299, test=105.50
# train=2300, test=66.50
# train=2301, test=55.00
# train=2302, test=58.40
# train=2303, test=68.30
# train=2304, test=45.60
# train=2305, test=44.50
# train=2306, test=46.40
# train=2307, test=32.80
# train=2308, test=29.50
# train=2309, test=59.80
# train=2310, test=66.90
# train=2311, test=60.00
# train=2312, test=65.90
# train=2313, test=46.30
# train=2314, test=38.30
# train=2315, test=33.70
# train=2316, test=35.60
# train=2317, test=52.80
# train=2318, test=54.20
# train=2319, test=60.70
# train=2320, test=25.00
# train=2321, test=11.40
# train=2322, test=17.70
# train=2323, test=20.20
# train=2324, test=17.20
# train=2325, test=19.20
# train=2326, test=30.70
# train=2327, test=22.50
# train=2328, test=12.40
# train=2329, test=28.90
# train=2330, test=27.40
# train=2331, test=26.10
# train=2332, test=14.10
# train=2333, test=7.60
# train=2334, test=13.20
# train=2335, test=19.40
# train=2336, test=10.00
# train=2337, test=7.80
# train=2338, test=10.20
# train=2339, test=18.80
# train=2340, test=3.70
# train=2341, test=0.50
# train=2342, test=11.00
# train=2343, test=0.30
# train=2344, test=2.50
# train=2345, test=5.00
# train=2346, test=5.00
# train=2347, test=16.70
# train=2348, test=14.30
# train=2349, test=16.90
# train=2350, test=10.80
# train=2351, test=28.40
# train=2352, test=18.50
# train=2353, test=12.70
# train=2354, test=21.50
# train=2355, test=32.00
# train=2356, test=30.60
# train=2357, test=36.20
# train=2358, test=42.60
# train=2359, test=25.90
# train=2360, test=34.90
# train=2361, test=68.80
# train=2362, test=46.00
# train=2363, test=27.40
# train=2364, test=47.60
# train=2365, test=86.20
# train=2366, test=76.60
# train=2367, test=75.70
# train=2368, test=84.90
# train=2369, test=73.50
# train=2370, test=116.20
# train=2371, test=107.20
# train=2372, test=94.40
# train=2373, test=102.30
# train=2374, test=123.80
# train=2375, test=121.70
# train=2376, test=115.70
# train=2377, test=113.40
# train=2378, test=129.80
# train=2379, test=149.80
# train=2380, test=201.30
# train=2381, test=163.90
# train=2382, test=157.90
# train=2383, test=188.80
# train=2384, test=169.40
# train=2385, test=163.60
# train=2386, test=128.00
# train=2387, test=116.50
# train=2388, test=108.50
# train=2389, test=86.10
# train=2390, test=94.80
# train=2391, test=189.70
# train=2392, test=174.00
# train=2393, test=167.80
# train=2394, test=142.20
# train=2395, test=157.90
# train=2396, test=143.30
# train=2397, test=136.30
# train=2398, test=95.80
# train=2399, test=138.00
# train=2400, test=119.10
# train=2401, test=182.30
# train=2402, test=157.50
# train=2403, test=147.00
# train=2404, test=106.20
# train=2405, test=121.70
# train=2406, test=125.80
# train=2407, test=123.80
# train=2408, test=145.30
# train=2409, test=131.60
# train=2410, test=143.50
# train=2411, test=117.60
# train=2412, test=101.60
# train=2413, test=94.80
# train=2414, test=109.70
# train=2415, test=113.40
# train=2416, test=106.20
# train=2417, test=83.60
# train=2418, test=91.00
# train=2419, test=85.20
# train=2420, test=51.30
# train=2421, test=61.40
# train=2422, test=54.80
# train=2423, test=54.10
# train=2424, test=59.90
# train=2425, test=59.90
# train=2426, test=59.90
# train=2427, test=92.90
# train=2428, test=108.50
# train=2429, test=100.60
# train=2430, test=61.50
# train=2431, test=61.00
# train=2432, test=83.10
# train=2433, test=51.60
# train=2434, test=52.40
# train=2435, test=45.80
# train=2436, test=40.70
# train=2437, test=22.70
# train=2438, test=22.00
# train=2439, test=29.10
# train=2440, test=23.40
# train=2441, test=36.40
# train=2442, test=39.30
# train=2443, test=54.90
# train=2444, test=28.20
# train=2445, test=23.80
# train=2446, test=22.10
# train=2447, test=34.30
# train=2448, test=26.50
# train=2449, test=3.90
# train=2450, test=10.00
# train=2451, test=27.80
# train=2452, test=12.50
# train=2453, test=21.80
# train=2454, test=8.60
# train=2455, test=23.50
# train=2456, test=19.30
# train=2457, test=8.20
# train=2458, test=1.60
# train=2459, test=2.50
# train=2460, test=0.20
# train=2461, test=0.50
# train=2462, test=10.90
# train=2463, test=1.80
# train=2464, test=0.80
# train=2465, test=0.20
# train=2466, test=4.80
# train=2467, test=8.40
# train=2468, test=1.50
# train=2469, test=7.00
# train=2470, test=9.20
# train=2471, test=7.60
# train=2472, test=23.10
# train=2473, test=20.80
# train=2474, test=4.90
# train=2475, test=11.30
# train=2476, test=28.90
# train=2477, test=31.70
# train=2478, test=26.70
# train=2479, test=40.70
# train=2480, test=42.70
# train=2481, test=58.50
# train=2482, test=89.20
# train=2483, test=76.90
# train=2484, test=73.60
# train=2485, test=124.00
# train=2486, test=118.40
# train=2487, test=110.70
# train=2488, test=136.60
# train=2489, test=116.60
# train=2490, test=129.10
# train=2491, test=169.60
# train=2492, test=173.20
# train=2493, test=155.30
# train=2494, test=201.30
# train=2495, test=192.10
# train=2496, test=165.00
# train=2497, test=130.20
# train=2498, test=157.40
# train=2499, test=175.20
# train=2500, test=164.60
# train=2501, test=200.70
# train=2502, test=187.20
# train=2503, test=158.00
# train=2504, test=235.80
# train=2505, test=253.80
# train=2506, test=210.90
# train=2507, test=239.40
# train=2508, test=202.50
# train=2509, test=164.90
# train=2510, test=190.70
# train=2511, test=196.00
# train=2512, test=175.30
# train=2513, test=171.50
# train=2514, test=191.40
# train=2515, test=200.20
# train=2516, test=201.20
# train=2517, test=181.50
# train=2518, test=152.30
# train=2519, test=187.60
# train=2520, test=217.40
# train=2521, test=143.10
# train=2522, test=185.70
# train=2523, test=163.30
# train=2524, test=172.00
# train=2525, test=168.70
# train=2526, test=149.60
# train=2527, test=199.60
# train=2528, test=145.20
# train=2529, test=111.40
# train=2530, test=124.00
# train=2531, test=125.00
# train=2532, test=146.30
# train=2533, test=106.00
# train=2534, test=102.20
# train=2535, test=122.00
# train=2536, test=119.60
# train=2537, test=110.20
# train=2538, test=121.70
# train=2539, test=134.10
# train=2540, test=127.20
# train=2541, test=82.80
# train=2542, test=89.60
# train=2543, test=85.60
# train=2544, test=57.90
# train=2545, test=46.10
# train=2546, test=53.00
# train=2547, test=61.40
# train=2548, test=51.00
# train=2549, test=77.40
# train=2550, test=70.20
# train=2551, test=55.90
# train=2552, test=63.60
# train=2553, test=37.70
# train=2554, test=32.60
# train=2555, test=40.00
# train=2556, test=38.70
# train=2557, test=50.30
# train=2558, test=45.60
# train=2559, test=46.40
# train=2560, test=43.70
# train=2561, test=42.00
# train=2562, test=21.80
# train=2563, test=21.80
# train=2564, test=51.30
# train=2565, test=39.50
# train=2566, test=26.90
# train=2567, test=23.20
# train=2568, test=19.80
# train=2569, test=24.40
# train=2570, test=17.10
# train=2571, test=29.30
# train=2572, test=43.00
# train=2573, test=35.90
# train=2574, test=19.60
# train=2575, test=33.20
# train=2576, test=38.80
# train=2577, test=35.30
# train=2578, test=23.40
# train=2579, test=14.90
# train=2580, test=15.30
# train=2581, test=17.70
# train=2582, test=16.50
# train=2583, test=8.60
# train=2584, test=9.50
# train=2585, test=9.10
# train=2586, test=3.10
# train=2587, test=9.30
# train=2588, test=4.70
# train=2589, test=6.10
# train=2590, test=7.40
# train=2591, test=15.10
# train=2592, test=17.50
# train=2593, test=14.20
# train=2594, test=11.70
# train=2595, test=6.80
# train=2596, test=24.10
# train=2597, test=15.90
# train=2598, test=11.90
# train=2599, test=8.90
# train=2600, test=16.80
# train=2601, test=20.10
# train=2602, test=15.80
# train=2603, test=17.00
# train=2604, test=28.20
# train=2605, test=24.40
# train=2606, test=25.30
# train=2607, test=48.70
# train=2608, test=45.30
# train=2609, test=47.70
# train=2610, test=56.70
# train=2611, test=51.20
# train=2612, test=50.20
# train=2613, test=57.20
# train=2614, test=57.20
# train=2615, test=70.40
# train=2616, test=110.90
# train=2617, test=93.60
# train=2618, test=111.80
# train=2619, test=69.50
# train=2620, test=86.50
# train=2621, test=67.30
# train=2622, test=91.50
# train=2623, test=107.20
# train=2624, test=76.80
# train=2625, test=88.20
# train=2626, test=94.30
# train=2627, test=126.40
# train=2628, test=121.80
# train=2629, test=111.90
# train=2630, test=92.20
# train=2631, test=81.20
# train=2632, test=127.20
# train=2633, test=110.30
# train=2634, test=96.10
# train=2635, test=109.30
# train=2636, test=117.20
# train=2637, test=107.70
# train=2638, test=86.00
# train=2639, test=109.80
# train=2640, test=104.40
# train=2641, test=120.50
# train=2642, test=135.80
# train=2643, test=106.80
# train=2644, test=120.00
# train=2645, test=106.00
# train=2646, test=96.80
# train=2647, test=98.00
# train=2648, test=91.30
# train=2649, test=95.70
# train=2650, test=93.50
# train=2651, test=97.90
# train=2652, test=111.50
# train=2653, test=127.80
# train=2654, test=102.90
# train=2655, test=109.50
# train=2656, test=127.50
# train=2657, test=106.80
# train=2658, test=112.50
# train=2659, test=93.00
# train=2660, test=99.50
# train=2661, test=86.60
# train=2662, test=95.20
# train=2663, test=83.50
# train=2664, test=91.30
# train=2665, test=79.00
# train=2666, test=60.70
# train=2667, test=71.80
# train=2668, test=57.50
# train=2669, test=49.80
# train=2670, test=81.00
# train=2671, test=61.40
# train=2672, test=50.20
# train=2673, test=51.70
# train=2674, test=63.20
# train=2675, test=82.20
# train=2676, test=61.50
# train=2677, test=88.40
# train=2678, test=80.10
# train=2679, test=63.20
# train=2680, test=80.50
# train=2681, test=88.00
# train=2682, test=76.50
# train=2683, test=76.80
# train=2684, test=64.00
# train=2685, test=61.30
# train=2686, test=41.60
# train=2687, test=45.30
# train=2688, test=43.40
# train=2689, test=42.90
# train=2690, test=46.00
# train=2691, test=57.70
# train=2692, test=42.40
# train=2693, test=39.50
# train=2694, test=23.10
# train=2695, test=25.60
# train=2696, test=59.30
# train=2697, test=30.70
# train=2698, test=23.90
# train=2699, test=23.30
# train=2700, test=27.60
# train=2701, test=26.00
# train=2702, test=21.30
# train=2703, test=40.30
# train=2704, test=39.50
# train=2705, test=36.00
# train=2706, test=55.80
# train=2707, test=33.60
# train=2708, test=40.20
# train=2709, test=47.10
# train=2710, test=25.00
# train=2711, test=20.50
# train=2712, test=18.90
# train=2713, test=11.50
# train=2714, test=11.50
# train=2715, test=5.10
# train=2716, test=9.00
# train=2717, test=11.40
# train=2718, test=28.20
# train=2719, test=39.70
# train=2720, test=13.90
# train=2721, test=9.10
# train=2722, test=19.40
# train=2723, test=7.80
# train=2724, test=8.10
# train=2725, test=4.30
# train=2726, test=21.90
# train=2727, test=18.80
# train=2728, test=12.40
# train=2729, test=12.20
# train=2730, test=1.90
# train=2731, test=16.40
# train=2732, test=13.50
# train=2733, test=20.60
# train=2734, test=5.20
# train=2735, test=15.30
# train=2736, test=16.40
# train=2737, test=23.10
# train=2738, test=8.70
# train=2739, test=12.90
# train=2740, test=18.60
# train=2741, test=38.50
# train=2742, test=21.40
# train=2743, test=30.10
# train=2744, test=44.00
# train=2745, test=43.80
# train=2746, test=29.10
# train=2747, test=43.20
# train=2748, test=51.90
# train=2749, test=93.60
# train=2750, test=76.50
# train=2751, test=99.70
# train=2752, test=82.70
# train=2753, test=95.10
# train=2754, test=70.40
# train=2755, test=58.10
# train=2756, test=138.20
# train=2757, test=125.10
# train=2758, test=97.90
# train=2759, test=122.70
# train=2760, test=166.60
# train=2761, test=137.50
# train=2762, test=138.00
# train=2763, test=101.50
# train=2764, test=134.40
# train=2765, test=149.50
# train=2766, test=159.40
# train=2767, test=142.20
# train=2768, test=188.40
# train=2769, test=186.20
# train=2770, test=183.30
# train=2771, test=176.30
# train=2772, test=159.60
# train=2773, test=155.00
# train=2774, test=126.20
# train=2775, test=164.10
# train=2776, test=179.90
# train=2777, test=157.30
# train=2778, test=136.30
# train=2779, test=135.40
# train=2780, test=155.00
# train=2781, test=164.70
# train=2782, test=147.90
# train=2783, test=174.40
# train=2784, test=114.00
# train=2785, test=141.30
# train=2786, test=135.50
# train=2787, test=156.40
# train=2788, test=127.50
# train=2789, test=90.00
# train=2790, test=143.80
# train=2791, test=158.70
# train=2792, test=167.30
# train=2793, test=162.40
# train=2794, test=137.50
# train=2795, test=150.10
# train=2796, test=111.20
# train=2797, test=163.60
# train=2798, test=153.80
# train=2799, test=122.00
# train=2800, test=82.20
# train=2801, test=110.40
# train=2802, test=106.10
# train=2803, test=107.60
# train=2804, test=118.80
# train=2805, test=94.70
# train=2806, test=98.10
# train=2807, test=127.00
# train=2808, test=84.30
# train=2809, test=51.00
# train=2810, test=66.50
# train=2811, test=80.70
# train=2812, test=99.20
# train=2813, test=91.10
# train=2814, test=82.20
# train=2815, test=71.80
# train=2816, test=50.30
# train=2817, test=55.80
# train=2818, test=33.30
# train=2819, test=33.40
